# %% [markdown]
# # Import data

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# นำเข้าข้อมูล การปรากฏตัวของโปเกมอนในเกม Pokemon Go

# %%
df = pd.read_csv('/content/drive/MyDrive/300k_csv/300k.csv')
# Out:
# <ipython-input-3-efe82204873c>:1: DtypeWarning: Columns (49) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/drive/MyDrive/300k_csv/300k.csv')

# %%
df.shape
# Out:
# (296021, 208)

# %%
df.head()
# Out:
#    pokemonId   latitude   longitude    appearedLocalTime  \
# 0         16  20.525745  -97.460829  2016-09-08T03:57:45
# 1        133  20.523695  -97.461167  2016-09-08T03:57:37
# 2         16  38.903590  -77.199780  2016-09-08T03:57:25
# 3         13  47.665903 -122.312561  2016-09-08T03:56:22
# 4        133  47.666454 -122.311628  2016-09-08T03:56:08
#
#                             _id           cellId_90m          cellId_180m  \
# 0  NTgxMDkzOTk4MTM5MjUwMjIzNw==  9645139108510564000  9645139108711890000
# 1  OTQ1NDgzODc1MjM3NDEzMTI2MQ==  9645139109852742000  9645139109785633000
# 2  NTQ0OTQ0NDA1Nzg2ODg3OTg2OQ==  9923201472785285000  9923201472986612000
# 3  NTU2MTU1NDM4NzA2MDk1MDcxNw==  6093392705025474600  6093392705092583400
# 4  MTY2ODg4MTAzMTczMDE0MTUwNTM=  6093392707709829100  6093392707776938000
#
#            cellId_370m          cellId_730m         cellId_1460m  ...  \
# 0  9645139108443455000  9645139109517197000  9645139113812165000  ...
# 1  9645139110590940000  9645139109517197000  9645139113812165000  ...
# 2  9923201473791918000  9923201477013144000  9923201481308110000  ...
# 3  6093392705897889800  6093392702676664300  6093392715561566200  ...
# 4  6093392708045373400  6093392711266598900  6093392715561566200  ...
#
#    cooc_143  cooc_144 cooc_145  cooc_146  cooc_147 cooc_148  cooc_149  \
# 0     False     False    False     False     False    False     False
# 1     False     False    False     False     False    False     False
# 2     False     False    False     False     False    False     False
# 3     False     False    False     False     False    False     False
# 4     False     False    False     False     False    False     False
#
#    cooc_150  cooc_151  class
# 0     False     False     16
# 1     False     False    133
# 2     False     False     16
# 3     False     False     13
# 4     False     False    133
#
# [5 rows x 208 columns]

# %% [markdown]
# เลือก columns ในส่วนที่สนใจและคาดว่าเป็นประโยชน์

# %%
selected_columns = ['pokemonId', 'latitude', 'longitude', 'appearedLocalTime', 'appearedTimeOfDay', 'terrainType', 'closeToWater', 'city', 'continent', 'weather', 'temperature', 'windSpeed', 'windBearing', 'pressure', 'weatherIcon', 'population_density', 'gymDistanceKm', 'pokestopDistanceKm']

pokemon_df = df.loc[:, selected_columns]
pokemon_df.head()
# Out:
#    pokemonId   latitude   longitude    appearedLocalTime appearedTimeOfDay  \
# 0         16  20.525745  -97.460829  2016-09-08T03:57:45             night
# 1        133  20.523695  -97.461167  2016-09-08T03:57:37             night
# 2         16  38.903590  -77.199780  2016-09-08T03:57:25             night
# 3         13  47.665903 -122.312561  2016-09-08T03:56:22             night
# 4        133  47.666454 -122.311628  2016-09-08T03:56:08             night
#
#    terrainType  closeToWater         city continent       weather  \
# 0           14         False  Mexico_City   America         Foggy
# 1           14         False  Mexico_City   America         Foggy
# 2           13         False     New_York   America         Clear
# 3            0          True  Los_Angeles   America  PartlyCloudy
# 4            0          True  Los_Angeles   America  PartlyCloudy
#
#    temperature  windSpeed  windBearing  pressure          weatherIcon  \
# 0         25.5       4.79          269   1018.02                  fog
# 1         25.5       4.79          269   1018.02                  fog
# 2         24.2       4.29          218   1015.29          clear-night
# 3         15.6       5.84          160   1020.52  partly-cloudy-night
# 4         15.6       5.84          160   1020.52  partly-cloudy-night
#
#    population_density  gymDistanceKm pokestopDistanceKm
# 0           2431.2341       0.049869           0.081776
# 1           2431.2341       0.259156           0.195622
# 2            761.8856       0.489886           0.338602
# 3           4842.1626       0.359309           0.109479
# 4           4842.1626       0.210543           0.040364

# %%
pokemon_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 296021 entries, 0 to 296020
# Data columns (total 18 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   pokemonId           296021 non-null  int64
#  1   latitude            296021 non-null  float64
#  2   longitude           296021 non-null  float64
#  3   appearedLocalTime   296021 non-null  object
#  4   appearedTimeOfDay   296021 non-null  object
#  5   terrainType         296021 non-null  int64
#  6   closeToWater        296021 non-null  bool
#  7   city                296021 non-null  object
#  8   continent           296021 non-null  object
#  9   weather             296021 non-null  object
#  10  temperature         296021 non-null  float64
#  11  windSpeed           296021 non-null  float64
#  12  windBearing         296021 non-null  int64
#  13  pressure            296021 non-null  float64
#  14  weatherIcon         296021 non-null  object
#  15  population_density  296021 non-null  float64
#  16  gymDistanceKm       296021 non-null  float64
#  17  pokestopDistanceKm  296021 non-null  object
# dtypes: bool(1), float64(7), int64(3), object(7)
# memory usage: 38.7+ MB

# %% [markdown]
# ข้อมูล Pokemon ตาม pokemonid

# %%
df = pd.read_csv('/content/drive/MyDrive/300k_csv/All_Pokemon.csv')

# %%
df.head()
# Out:
#    Number           Name Type 1  Type 2                    Abilities  HP  Att  \
# 0       1      Bulbasaur  Grass  Poison  ['Chlorophyll', 'Overgrow']  45   49
# 1       2        Ivysaur  Grass  Poison  ['Chlorophyll', 'Overgrow']  60   62
# 2       3       Venusaur  Grass  Poison  ['Chlorophyll', 'Overgrow']  80   82
# 3       3  Mega Venusaur  Grass  Poison                ['Thick Fat']  80  100
# 4       4     Charmander   Fire     NaN     ['Blaze', 'Solar Power']  39   52
#
#    Def  Spa  Spd  ...  Against Bug  Against Rock  Against Ghost  \
# 0   49   65   65  ...          1.0           1.0            1.0
# 1   63   80   80  ...          1.0           1.0            1.0
# 2   83  100  100  ...          1.0           1.0            1.0
# 3  123  122  120  ...          1.0           1.0            1.0
# 4   43   60   50  ...          0.5           2.0            1.0
#
#    Against Dragon  Against Dark Against Steel  Against Fairy  Height  Weight  \
# 0             1.0           1.0           1.0            0.5     0.7     6.9
# 1             1.0           1.0           1.0            0.5     1.0    13.0
# 2             1.0           1.0           1.0            0.5     2.0   100.0
# 3             1.0           1.0           1.0            0.5     2.4   155.5
# 4             1.0           1.0           0.5            0.5     0.6     8.5
#
#     BMI
# 0  14.1
# 1  13.0
# 2  25.0
# 3  27.0
# 4  23.6
#
# [5 rows x 44 columns]

# %% [markdown]
# เนื่องจาากใน dataset แรกมีเลข pokemonid เพียง 1-151 หรือ pokemon generation 1

# %%
df = df[df['Generation'] == 1]

# %%
selected_columns = ['Number','Name','Type 1','Type 2']
pokedex_df = df.loc[:, selected_columns]
pokedex_df.head()
# Out:
#    Number        Name Type 1  Type 2
# 0       1   Bulbasaur  Grass  Poison
# 1       2     Ivysaur  Grass  Poison
# 2       3    Venusaur  Grass  Poison
# 4       4  Charmander   Fire     NaN
# 5       5  Charmeleon   Fire     NaN

# %% [markdown]
# เปลี่ยน column Number เป็น pokemonId เพื่อใช้ในการ join ตาราง

# %%
new_column_names = {
    'Number': 'pokemonId',
}
pokedex_df = pokedex_df.rename(columns=new_column_names)
pokedex_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 151 entries, 0 to 194
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pokemonId  151 non-null    int64
#  1   Name       151 non-null    object
#  2   Type 1     151 non-null    object
#  3   Type 2     67 non-null     object
# dtypes: int64(1), object(3)
# memory usage: 5.9+ KB

# %%
pokemon_df = pd.merge(pokemon_df, pokedex_df, on='pokemonId',how='left')

# %%
pokemon_df.head()
# Out:
#    pokemonId   latitude   longitude    appearedLocalTime appearedTimeOfDay  \
# 0         16  20.525745  -97.460829  2016-09-08T03:57:45             night
# 1        133  20.523695  -97.461167  2016-09-08T03:57:37             night
# 2         16  38.903590  -77.199780  2016-09-08T03:57:25             night
# 3         13  47.665903 -122.312561  2016-09-08T03:56:22             night
# 4        133  47.666454 -122.311628  2016-09-08T03:56:08             night
#
#    terrainType  closeToWater         city continent       weather  ...  \
# 0           14         False  Mexico_City   America         Foggy  ...
# 1           14         False  Mexico_City   America         Foggy  ...
# 2           13         False     New_York   America         Clear  ...
# 3            0          True  Los_Angeles   America  PartlyCloudy  ...
# 4            0          True  Los_Angeles   America  PartlyCloudy  ...
#
#    windSpeed  windBearing  pressure          weatherIcon population_density  \
# 0       4.79          269   1018.02                  fog          2431.2341
# 1       4.79          269   1018.02                  fog          2431.2341
# 2       4.29          218   1015.29          clear-night           761.8856
# 3       5.84          160   1020.52  partly-cloudy-night          4842.1626
# 4       5.84          160   1020.52  partly-cloudy-night          4842.1626
#
#    gymDistanceKm  pokestopDistanceKm    Name  Type 1  Type 2
# 0       0.049869            0.081776  Pidgey  Normal  Flying
# 1       0.259156            0.195622   Eevee  Normal     NaN
# 2       0.489886            0.338602  Pidgey  Normal  Flying
# 3       0.359309            0.109479  Weedle     Bug  Poison
# 4       0.210543            0.040364   Eevee  Normal     NaN
#
# [5 rows x 21 columns]

# %%
pokemon_rarity = {
    1: 'Rare', 2: 'Rare', 3: 'Rare', 4: 'Rare', 5: 'Rare', 6: 'Rare',
    7: 'Rare', 8: 'Rare', 9: 'Rare', 10: 'Uncommon', 11: 'Uncommon',
    12: 'Uncommon', 13: 'Common', 14: 'Common', 15: 'Common', 16: 'Common',
    17: 'Common', 18: 'Common', 19: 'Common', 20: 'Common', 21: 'Uncommon',
    22: 'Uncommon', 23: 'Uncommon', 24: 'Uncommon', 25: 'Rare', 26: 'Rare',
    27: 'Rare', 28: 'Rare', 29: 'Uncommon', 30: 'Uncommon', 31: 'Uncommon',
    32: 'Uncommon', 33: 'Uncommon', 34: 'Uncommon', 35: 'Rare', 36: 'Rare',
    37: 'Rare', 38: 'Rare', 39: 'Rare', 40: 'Rare', 41: 'Common', 42: 'Common',
    43: 'Uncommon', 44: 'Uncommon', 45: 'Uncommon', 46: 'Uncommon', 47: 'Uncommon',
    48: 'Uncommon', 49: 'Uncommon', 50: 'Rare', 51: 'Rare', 52: 'Rare', 53: 'Rare',
    54: 'Rare', 55: 'Rare', 56: 'Rare', 57: 'Rare', 58: 'Uncommon', 59: 'Uncommon',
    60: 'Uncommon', 61: 'Uncommon', 62: 'Uncommon', 63: 'Rare', 64: 'Rare', 65: 'Rare',
    66: 'Rare', 67: 'Rare', 68: 'Rare', 69: 'Uncommon', 70: 'Uncommon', 71: 'Uncommon',
    72: 'Rare', 73: 'Rare', 74: 'Rare', 75: 'Rare', 76: 'Rare', 77: 'Rare', 78: 'Rare',
    79: 'Rare', 80: 'Rare', 81: 'Rare', 82: 'Rare', 83: 'Super Rare', 84: 'Uncommon',
    85: 'Uncommon', 86: 'Rare', 87: 'Rare', 88: 'Very Rare', 89: 'Very Rare', 90: 'Rare',
    91: 'Rare', 92: 'Uncommon', 93: 'Uncommon', 94: 'Uncommon', 95: 'Rare', 96: 'Rare',
    97: 'Uncommon', 98: 'Rare', 99: 'Uncommon', 100: 'Rare', 101: 'Rare', 102: 'Rare',
    103: 'Rare', 104: 'Rare', 105: 'Rare', 106: 'Very Rare', 107: 'Very Rare', 108: 'Very Rare',
    109: 'Rare', 110: 'Rare', 111: 'Rare', 112: 'Rare', 113: 'Very Rare', 114: 'Rare',
    115: 'Super Rare', 116: 'Rare', 117: 'Rare', 118: 'Rare', 119: 'Rare', 120: 'Uncommon',
    121: 'Uncommon', 122: 'Super Rare', 123: 'Rare', 124: 'Rare', 125: 'Rare', 126: 'Rare',
    127: 'Uncommon', 128: 'Rare', 129: 'Very Rare', 130: 'Very Rare', 131: 'Super Rare',
    132: 'Super Rare', 133: 'Rare', 134: 'Rare', 135: 'Rare', 136: 'Rare', 137: 'Very Rare',
    138: 'Rare', 139: 'Rare', 140: 'Rare', 141: 'Rare', 142: 'Very Rare', 143: 'Rare',
    144: 'Super Rare', 145: 'Super Rare', 146: 'Super Rare', 147: 'Rare', 148: 'Rare',
    149: 'Rare', 150: 'Super Rare', 151: 'Super Rare'
}

# %%
pokemon_df['rarity'] = pokemon_df['pokemonId'].map(pokemon_rarity)

# %%
pokemon_df.head(5)
# Out:
#    pokemonId   latitude   longitude    appearedLocalTime appearedTimeOfDay  \
# 0         16  20.525745  -97.460829  2016-09-08T03:57:45             night
# 1        133  20.523695  -97.461167  2016-09-08T03:57:37             night
# 2         16  38.903590  -77.199780  2016-09-08T03:57:25             night
# 3         13  47.665903 -122.312561  2016-09-08T03:56:22             night
# 4        133  47.666454 -122.311628  2016-09-08T03:56:08             night
#
#    terrainType  closeToWater         city continent       weather  ...  \
# 0           14         False  Mexico_City   America         Foggy  ...
# 1           14         False  Mexico_City   America         Foggy  ...
# 2           13         False     New_York   America         Clear  ...
# 3            0          True  Los_Angeles   America  PartlyCloudy  ...
# 4            0          True  Los_Angeles   America  PartlyCloudy  ...
#
#    windBearing  pressure          weatherIcon  population_density  \
# 0          269   1018.02                  fog           2431.2341
# 1          269   1018.02                  fog           2431.2341
# 2          218   1015.29          clear-night            761.8856
# 3          160   1020.52  partly-cloudy-night           4842.1626
# 4          160   1020.52  partly-cloudy-night           4842.1626
#
#   gymDistanceKm  pokestopDistanceKm    Name  Type 1  Type 2  rarity
# 0      0.049869            0.081776  Pidgey  Normal  Flying  Common
# 1      0.259156            0.195622   Eevee  Normal     NaN    Rare
# 2      0.489886            0.338602  Pidgey  Normal  Flying  Common
# 3      0.359309            0.109479  Weedle     Bug  Poison  Common
# 4      0.210543            0.040364   Eevee  Normal     NaN    Rare
#
# [5 rows x 22 columns]

# %% [markdown]
# # 1 ) Clean data

# %% [markdown]
# เนื่องจาก data type ของ appearedLocalTime เป็น object จึงเปลี่ยนให้เป็น datetime เพื่อให้ง่ายต่อการใช้งาน

# %%
pokemon_df['appearedLocalTime'] = pd.to_datetime(pokemon_df['appearedLocalTime'], format='%Y-%m-%dT%H:%M:%S')

# %%
pokemon_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 296021 entries, 0 to 296020
# Data columns (total 22 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   pokemonId           296021 non-null  int64
#  1   latitude            296021 non-null  float64
#  2   longitude           296021 non-null  float64
#  3   appearedLocalTime   296021 non-null  datetime64[ns]
#  4   appearedTimeOfDay   296021 non-null  object
#  5   terrainType         296021 non-null  int64
#  6   closeToWater        296021 non-null  bool
#  7   city                296021 non-null  object
#  8   continent           296021 non-null  object
#  9   weather             296021 non-null  object
#  10  temperature         296021 non-null  float64
#  11  windSpeed           296021 non-null  float64
#  12  windBearing         296021 non-null  int64
#  13  pressure            296021 non-null  float64
#  14  weatherIcon         296021 non-null  object
#  15  population_density  296021 non-null  float64
#  16  gymDistanceKm       296021 non-null  float64
#  17  pokestopDistanceKm  296021 non-null  object
#  18  Name                296021 non-null  object
#  19  Type 1              296021 non-null  object
#  20  Type 2              151211 non-null  object
#  21  rarity              296021 non-null  object
# dtypes: bool(1), datetime64[ns](1), float64(7), int64(3), object(10)
# memory usage: 47.7+ MB

# %% [markdown]
# check null ในแต่ละ column

# %%
pokemon_df.isnull().any()
# Out:
# pokemonId             False
# latitude              False
# longitude             False
# appearedLocalTime     False
# appearedTimeOfDay     False
# terrainType           False
# closeToWater          False
# city                  False
# continent             False
# weather               False
# temperature           False
# windSpeed             False
# windBearing           False
# pressure              False
# weatherIcon           False
# population_density    False
# gymDistanceKm         False
# pokestopDistanceKm    False
# Name                  False
# Type 1                False
# Type 2                 True
# rarity                False
# dtype: bool

# %% [markdown]
# มีเพียง Type 2 ที่มีค่าเป็น null ซึ่งสามารถยอมรับได้เนื่องจากโปเกมอนบางตัวมีธาตุเดียว

# %% [markdown]
# ตรวจสอบแถวที่มีค่าซ้ำกัน

# %%
pokemon_df[pokemon_df.duplicated()].head()
# Out:
# Empty DataFrame
# Columns: [pokemonId, latitude, longitude, appearedLocalTime, appearedTimeOfDay, terrainType, closeToWater, city, continent, weather, temperature, windSpeed, windBearing, pressure, weatherIcon, population_density, gymDistanceKm, pokestopDistanceKm, Name, Type 1, Type 2, rarity]
# Index: []
#
# [0 rows x 22 columns]

# %% [markdown]
# ไม่พบแถวที่มีค่าซ้ากัน

# %% [markdown]
# เนื่องจาก datatype ของ pokestopDistanceKm เป็น object ซึ่งควรเป็น float จึงทำการตรวจสอบค่าที่ไม่ใช่ตัวเลข

# %%
non_numeric_values = pokemon_df.loc[~pokemon_df['pokestopDistanceKm'].apply(pd.to_numeric, errors='coerce').notna(), 'pokestopDistanceKm']

print(non_numeric_values)
# Out:
# 24570     ?
# 33459     ?
# 45025     ?
# 47999     ?
# 48090     ?
# 60374     ?
# 61009     ?
# 63813     ?
# 64236     ?
# 64515     ?
# 66526     ?
# 67702     ?
# 67995     ?
# 68305     ?
# 75340     ?
# 75836     ?
# 94313     ?
# 94440     ?
# 132945    ?
# 133599    ?
# 136223    ?
# 142960    ?
# 143493    ?
# 146630    ?
# 147084    ?
# 161321    ?
# 167224    ?
# 206038    ?
# 210427    ?
# 221327    ?
# 221580    ?
# 227290    ?
# 227315    ?
# 231451    ?
# 261021    ?
# 272505    ?
# 273387    ?
# 273987    ?
# 284535    ?
# Name: pokestopDistanceKm, dtype: object

# %% [markdown]
# พบค่าที่ไม่ใช่ตัวเลขซึ่งเป็นส่วนน้อยเทียบกับจำนวนแถวทั้งหมดจึงทำการ drop ทิ้ง และเปลี่ยน data type ให้เป็น float

# %%
pokemon_df.drop(pokemon_df[pokemon_df['pokestopDistanceKm'] == '?'].index, inplace=True)

# %%
pokemon_df['pokestopDistanceKm'] = pokemon_df['pokestopDistanceKm'].astype(float)

# %% [markdown]
# เนื่องจาก Terrian type แสดงค่าเป็นตัวเลขแทนภูมิประเทศในแต่ล่ะแบบ ทำให้ยากต่อการระบุจึงเปลี่ยนค่าที่อธิบายในแต่ล่ะภูมิประเทศ

# %%
terrain_mapping = {
    0: 'Water Bodies',
    1: 'Evergreen Needleleaf Forest',
    2: 'Evergreen Broadleaf Forest',
    3: 'Deciduous Needleleaf Forest',
    4: 'Deciduous Broadleaf Forest',
    5: 'Mixed Forest',
    6: 'Closed Shrublands',
    7: 'Open Shrublands',
    8: 'Woody Savannas',
    9: 'Savannas',
    10: 'Grasslands',
    11: 'Permanent Wetlands',
    12: 'Croplands',
    13: 'Urban and Built-up',
    14: 'Cropland/Natural Vegetation Mosaics',
    15: 'Permanent Snow and Ice',
    16: 'Barren'
}

pokemon_df['terrainType'] = pokemon_df['terrainType'].map(terrain_mapping)

# %%
terrain_counts = pokemon_df['weather'].value_counts()

print(terrain_counts)
# Out:
# weather
# Clear                    170457
# PartlyCloudy              48345
# MostlyCloudy              46582
# Overcast                  14419
# LightRain                  4487
# Drizzle                    4237
# Rain                       1335
# Foggy                      1291
# Breezy                      983
# Dry                         897
# Humid                       609
# BreezyandPartlyCloudy       534
# HumidandOvercast            355
# HeavyRain                   352
# BreezyandOvercast           230
# Windy                       208
# DrizzleandBreezy            160
# DangerouslyWindy             89
# LightRainandBreezy           78
# DryandPartlyCloudy           77
# BreezyandMostlyCloudy        72
# WindyandFoggy                68
# DryandMostlyCloudy           55
# RainandWindy                 41
# HumidandPartlyCloudy         16
# WindyandPartlyCloudy          5
# Name: count, dtype: int64

# %%
pokemon_df.describe()
# Out:
#            pokemonId       latitude      longitude  \
# count  295982.000000  295982.000000  295982.000000
# mean       45.318536      38.775996     -35.711094
# min         1.000000     -42.984504    -159.332033
# 25%        16.000000      33.810830     -90.237842
# 50%        21.000000      42.248317     -71.120435
# 75%        69.000000      49.478777      12.567947
# max       149.000000      68.438473     175.616223
# std        39.603665      17.028154      67.391078
#
#                    appearedLocalTime    temperature      windSpeed  \
# count                         295982  295982.000000  295982.000000
# mean   2016-09-05 08:25:17.762015488      21.730541       6.690806
# min              2016-09-02 21:50:06       4.200000       0.000000
# 25%    2016-09-04 05:29:38.249999872      17.100000       3.560000
# 50%              2016-09-05 09:35:53      21.600000       6.050000
# 75%       2016-09-06 11:25:42.500000      26.500000       8.870000
# max              2016-09-08 03:57:45      41.200000      56.130000
# std                              NaN       6.193058       4.174668
#
#          windBearing       pressure  population_density  gymDistanceKm  \
# count  295982.000000  295982.000000       295982.000000  295982.000000
# mean      179.912275    1016.116356         1313.411923       2.149323
# min         0.000000     996.330000            0.000000       0.000591
# 25%        96.000000    1012.160000          160.222840       0.183449
# 50%       190.000000    1016.510000          570.040200       0.334490
# 75%       261.000000    1019.970000         1691.790000       0.636270
# max       359.000000    1035.490000        10000.000000    3859.424664
# std        99.943296       5.633577         1913.532688      18.647361
#
#        pokestopDistanceKm
# count       295982.000000
# mean             0.695836
# min              0.000244
# 25%              0.066350
# 50%              0.156250
# 75%              0.367004
# max            455.961075
# std              6.855852

# %%
pokemon_df.head()
# Out:
#    pokemonId   latitude   longitude   appearedLocalTime appearedTimeOfDay  \
# 0         16  20.525745  -97.460829 2016-09-08 03:57:45             night
# 1        133  20.523695  -97.461167 2016-09-08 03:57:37             night
# 2         16  38.903590  -77.199780 2016-09-08 03:57:25             night
# 3         13  47.665903 -122.312561 2016-09-08 03:56:22             night
# 4        133  47.666454 -122.311628 2016-09-08 03:56:08             night
#
#                            terrainType  closeToWater         city continent  \
# 0  Cropland/Natural Vegetation Mosaics         False  Mexico_City   America
# 1  Cropland/Natural Vegetation Mosaics         False  Mexico_City   America
# 2                   Urban and Built-up         False     New_York   America
# 3                         Water Bodies          True  Los_Angeles   America
# 4                         Water Bodies          True  Los_Angeles   America
#
#         weather  ...  windBearing  pressure          weatherIcon  \
# 0         Foggy  ...          269   1018.02                  fog
# 1         Foggy  ...          269   1018.02                  fog
# 2         Clear  ...          218   1015.29          clear-night
# 3  PartlyCloudy  ...          160   1020.52  partly-cloudy-night
# 4  PartlyCloudy  ...          160   1020.52  partly-cloudy-night
#
#    population_density gymDistanceKm  pokestopDistanceKm    Name  Type 1  \
# 0           2431.2341      0.049869            0.081776  Pidgey  Normal
# 1           2431.2341      0.259156            0.195622   Eevee  Normal
# 2            761.8856      0.489886            0.338602  Pidgey  Normal
# 3           4842.1626      0.359309            0.109479  Weedle     Bug
# 4           4842.1626      0.210543            0.040364   Eevee  Normal
#
#    Type 2  rarity
# 0  Flying  Common
# 1     NaN    Rare
# 2  Flying  Common
# 3  Poison  Common
# 4     NaN    Rare
#
# [5 rows x 22 columns]

# %% [markdown]
# # 2 ) EDA

# %% [markdown]
# ## Rarity encounter

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Plot the rarity distribution
plt.figure(figsize=(10, 6))
ax = sns.countplot(data=pokemon_df, x='rarity', order=pokemon_df['rarity'].value_counts().index)
plt.title('Rarity Distribution of Pokémon')
plt.xlabel('Rarity')
plt.ylabel('Encounter times')
plt.xticks(rotation=45)

# Add labels with percentage
total = len(pokemon_df['rarity'])
for p in ax.patches:
    percentage = '{:.1f}%'.format(100 * p.get_height() / total)
    x = p.get_x() + p.get_width() / 2 - 0.05
    y = p.get_height() + 500
    ax.annotate(percentage, (x, y), fontsize=12)

plt.show()

# %% [markdown]
#  ## Encounter location

# %% [markdown]
# ต้องการทราบการปรากฏของโปเกม่อนในเกมเทียบกับแผนที่โลก

# %%
pip install basemap
# Out:
# Collecting basemap
#   Downloading basemap-1.4.1-cp310-cp310-manylinux1_x86_64.whl (935 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 936.0/936.0 kB 6.4 MB/s eta 0:00:00
# Collecting basemap-data<1.4,>=1.3.2 (from basemap)
#   Downloading basemap_data-1.3.2-py2.py3-none-any.whl (30.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.5/30.5 MB 604.9 kB/s eta 0:00:00
# Requirement already satisfied: pyshp<2.4,>=1.2 in /usr/local/lib/python3.10/dist-packages (from basemap) (2.3.1)
# Requirement already satisfied: matplotlib<3.9,>=1.5 in /usr/local/lib/python3.10/dist-packages (from basemap) (3.7.1)
# Requirement already satisfied: pyproj<3.7.0,>=1.9.3 in /usr/local/lib/python3.10/dist-packages (from basemap) (3.6.1)
# Collecting packaging<24.0,>=16.0 (from basemap)
#   Downloading packaging-23.2-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 435.0 kB/s eta 0:00:00
# Requirement already satisfied: numpy<1.27,>=1.21 in /usr/local/lib/python3.10/dist-packages (from basemap) (1.25.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.9,>=1.5->basemap) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.9,>=1.5->basemap) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.9,>=1.5->basemap) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.9,>=1.5->basemap) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.9,>=1.5->basemap) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.9,>=1.5->basemap) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.9,>=1.5->basemap) (2.8.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from pyproj<3.7.0,>=1.9.3->basemap) (2024.2.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib<3.9,>=1.5->basemap) (1.16.0)
# Installing collected packages: packaging, basemap-data, basemap
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.0
#     Uninstalling packaging-24.0:
#       Successfully uninstalled packaging-24.0
# Successfully installed basemap-1.4.1 basemap-data-1.3.2 packaging-23.2

# %%
import numpy as np # linear algebra
from mpl_toolkits.basemap import Basemap
from matplotlib import animation
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.figure(1, figsize=(20,10))
m1 = Basemap(projection='merc',
             llcrnrlat=-60,
             urcrnrlat=65,
             llcrnrlon=-180,
             urcrnrlon=180,
             lat_ts=0,
             resolution='c')

m1.fillcontinents(color='#191919',lake_color='#000000') # dark grey land, black lakes
m1.drawmapboundary(fill_color='#000000')                # black background
m1.drawcountries(linewidth=0.1, color="w")              # thin white line for country borders


x, y = m1(pokemon_df.longitude.tolist(),pokemon_df.latitude.tolist())
m1.scatter(x,y, s=3, c="#1292db", lw=0, alpha=1, zorder=5)
plt.title("Pokemon activity")
plt.show()

# %% [markdown]
# จากภาพ จะเห็นได้ว่าข้อมูลส่วนใหญ่ของการจับโปเกม่อนใน dataset นี้จะมาจากทวีปยุโรปกับสหรัฐอเมริกาเป็นหลัก

# %% [markdown]
# ส่วนใหญ่ข้อมูลถ้านอกจากยุโรปแล้ว จะอยู่ประเทศและเมืองที่มีคนท่องเที่ยวอยู่บ้าง เช่น ญี่ปุ่น ออสเตเรีย ไทย มาเลเซีย บราซิล เม็กซิโก UAE

# %% [markdown]
# ที่น่าสนใจเพิ่มเติมคือ ในจีนมีการจับโปเกม่อนแค่จุดเดียว นั่นเพราะสาเหตุคือจีนแบน Service ของ Google Map ซึ่ง Pokemon Go ใช้อ้างอิง แต่มีโซนเล็ก ๆ ที่รอด

# %% [markdown]
# ## (Test) Rarity by Location

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap

# Assuming 'pokemon_df' is your DataFrame and 'rarity' is a column in it

rarities = ["Common", "Rare", "Uncommon", "Super Rare", "Very Rare"]

# Create a separate map for each rarity
for rarity in rarities:
    plt.figure(figsize=(20, 10))
    m = Basemap(projection='merc',
                llcrnrlat=-60,
                urcrnrlat=65,
                llcrnrlon=-180,
                urcrnrlon=180,
                lat_ts=0,
                resolution='c')

    m.fillcontinents(color='#191919', lake_color='#000000') # dark grey land, black lakes
    m.drawmapboundary(fill_color='#000000')                # black background
    m.drawcountries(linewidth=0.1, color="w")              # thin white line for country borders

    # Filter DataFrame by rarity
    filtered_df = pokemon_df[pokemon_df['rarity'] == rarity]

    x, y = m(filtered_df.longitude.tolist(), filtered_df.latitude.tolist())
    m.scatter(x, y, s=3, c="#1292db", lw=0, alpha=1, zorder=5)
    plt.title(f"Pokemon activity - {rarity}")
    plt.show()

# %% [markdown]
# ## Gif by hour

# %% [markdown]
# ต้องการทราบการปรากฏของโปเกนมอนในเกมเทยบกับแผนที่โลกในแต่ล่ะชม.ตามเวลาท้องถิ่น

# %%
pokemon_df['appearedHour'] = pokemon_df['appearedLocalTime'].dt.hour

# %%
time_groups = pokemon_df.groupby('appearedHour')
plt.figure(1, figsize=(20,10))
m = map = Basemap(
    projection='merc',
    llcrnrlat=-60,
             urcrnrlat=65,
             llcrnrlon=-180,
             urcrnrlon=180,
             lat_ts=0,
    resolution='i')
m.fillcontinents(color='#191919',lake_color='#000000') # dark grey land, black lakes
m.drawmapboundary(fill_color='#000000')                # black background
m.drawcountries(linewidth=0.1, color="w")              # thin white line for country borders

x,y = m(0, 0)
point = m.plot(x, y, 'o', markersize=2, color='b')[0]
def init():
    point.set_data([], [])
    return point,

def animate(i):
    lon = time_groups.get_group(i)['longitude'].values
    lat = time_groups.get_group(i)['latitude'].values
    x, y = m(lon ,lat)
    point.set_data(x,y)
    plt.title('Pokemon activity at %2d:00' % (i))
    return point,

output = animation.FuncAnimation(plt.gcf(), animate, init_func=init, frames=24, interval=500, blit=True, repeat=False)
output.save("pokemon.gif", writer='imagemagick')
plt.show()
# Out:
# WARNING:matplotlib.animation:MovieWriter imagemagick unavailable; using Pillow instead.

# %%
pokemon_df.drop(columns='appearedHour', inplace=True)

# %% [markdown]
# ## Pokemon type by weather

# %% [markdown]
# ต้องการทราบความสัมพันธ์ของภูมิอากาศว่ามีผลต่อการปรากฏตัวของโปเกมอนในแต่ละธาตุหรือไม่

# %%
weather_counts_by_type_1 = pokemon_df.pivot_table(index='weather', columns='Type 1', aggfunc='size', fill_value=0)

# %%
weather_counts_by_type_2 = pokemon_df.pivot_table(index='weather', columns='Type 2', aggfunc='size', fill_value=0)

# %%
weather_counts_by_type_combine = weather_counts_by_type_1.add(weather_counts_by_type_2, fill_value=0)

# %%
weather_counts_by_type_combine.head(10)
# Out:
#                            Bug  Dragon  Electric  Fairy  Fighting    Fire  \
# weather
# Breezy                   140.0     1.0      62.0     13        10    21.0
# BreezyandMostlyCloudy      8.0     0.0       2.0      1         1     0.0
# BreezyandOvercast         33.0     0.0      13.0      2         0     3.0
# BreezyandPartlyCloudy    121.0     0.0       4.0     10         0     8.0
# Clear                  32451.0   385.0    1600.0   2833      1862  3055.0
# DangerouslyWindy          20.0     0.0       1.0      0         0     0.0
# Drizzle                  959.0    11.0      30.0     78        14    21.0
# DrizzleandBreezy          21.0     0.0       1.0      0         0     3.0
# Dry                      190.0     0.0       5.0     16         8     7.0
# DryandMostlyCloudy         7.0     0.0       0.0      1         0     0.0
#
#                         Flying   Ghost  Grass  Ground  Ice   Normal  Poison  \
# weather
# Breezy                   223.0     9.0     43      21    1    352.0     223
# BreezyandMostlyCloudy     24.0     0.0      1       1    0     28.0      10
# BreezyandOvercast         42.0     1.0     18       0    0     64.0      63
# BreezyandPartlyCloudy    147.0     5.0     34       3    0    263.0     150
# Clear                  46265.0  1254.0  11525    5450  397  73997.0   42812
# DangerouslyWindy          29.0     0.0      8       0    0     50.0      16
# Drizzle                 1256.0    42.0    244      31   12   2015.0    1102
# DrizzleandBreezy          49.0     8.0      7       1    2     83.0      31
# Dry                      248.0    11.0     57      26    3    338.0     249
# DryandMostlyCloudy        22.0     0.0      4       0    0     34.0      11
#
#                        Psychic  Rock  Steel  Water
# weather
# Breezy                      52    18   25.0    214
# BreezyandMostlyCloudy        5     0    1.0     24
# BreezyandOvercast           10     0    3.0     66
# BreezyandPartlyCloudy       30     1    2.0     43
# Clear                     8940  3044  580.0  20257
# DangerouslyWindy             0     1    0.0     11
# Drizzle                    237    23    9.0    480
# DrizzleandBreezy            14     0    0.0     23
# Dry                         68    16    2.0    119
# DryandMostlyCloudy           1     0    0.0      8

# %% [markdown]
# เนื่องจากข้อมูลมีระยะห่างมากเกินไปจึงทำการ normalize โดยหารด้วยผลรวมของทั้งแถว

# %%
weather_counts_by_type_normalize = weather_counts_by_type_combine.div(weather_counts_by_type_combine.sum(axis=1), axis=0)

# %%
weather_counts_by_type_normalize.head(10)
# Out:
#                             Bug    Dragon  Electric     Fairy  Fighting  \
# weather
# Breezy                 0.098039  0.000700  0.043417  0.009104  0.007003
# BreezyandMostlyCloudy  0.075472  0.000000  0.018868  0.009434  0.009434
# BreezyandOvercast      0.103774  0.000000  0.040881  0.006289  0.000000
# BreezyandPartlyCloudy  0.147381  0.000000  0.004872  0.012180  0.000000
# Clear                  0.126413  0.001500  0.006233  0.011036  0.007253
# DangerouslyWindy       0.147059  0.000000  0.007353  0.000000  0.000000
# Drizzle                0.146100  0.001676  0.004570  0.011883  0.002133
# DrizzleandBreezy       0.086420  0.000000  0.004115  0.000000  0.000000
# Dry                    0.139398  0.000000  0.003668  0.011739  0.005869
# DryandMostlyCloudy     0.079545  0.000000  0.000000  0.011364  0.000000
#
#                            Fire    Flying     Ghost     Grass    Ground  \
# weather
# Breezy                 0.014706  0.156162  0.006303  0.030112  0.014706
# BreezyandMostlyCloudy  0.000000  0.226415  0.000000  0.009434  0.009434
# BreezyandOvercast      0.009434  0.132075  0.003145  0.056604  0.000000
# BreezyandPartlyCloudy  0.009744  0.179050  0.006090  0.041413  0.003654
# Clear                  0.011901  0.180225  0.004885  0.044896  0.021230
# DangerouslyWindy       0.000000  0.213235  0.000000  0.058824  0.000000
# Drizzle                0.003199  0.191347  0.006399  0.037172  0.004723
# DrizzleandBreezy       0.012346  0.201646  0.032922  0.028807  0.004115
# Dry                    0.005136  0.181952  0.008070  0.041820  0.019076
# DryandMostlyCloudy     0.000000  0.250000  0.000000  0.045455  0.000000
#
#                             Ice    Normal    Poison   Psychic      Rock  \
# weather
# Breezy                 0.000700  0.246499  0.156162  0.036415  0.012605
# BreezyandMostlyCloudy  0.000000  0.264151  0.094340  0.047170  0.000000
# BreezyandOvercast      0.000000  0.201258  0.198113  0.031447  0.000000
# BreezyandPartlyCloudy  0.000000  0.320341  0.182704  0.036541  0.001218
# Clear                  0.001547  0.288255  0.166774  0.034826  0.011858
# DangerouslyWindy       0.000000  0.367647  0.117647  0.000000  0.007353
# Drizzle                0.001828  0.306977  0.167885  0.036106  0.003504
# DrizzleandBreezy       0.008230  0.341564  0.127572  0.057613  0.000000
# Dry                    0.002201  0.247982  0.182685  0.049890  0.011739
# DryandMostlyCloudy     0.000000  0.386364  0.125000  0.011364  0.000000
#
#                           Steel     Water
# weather
# Breezy                 0.017507  0.149860
# BreezyandMostlyCloudy  0.009434  0.226415
# BreezyandOvercast      0.009434  0.207547
# BreezyandPartlyCloudy  0.002436  0.052375
# Clear                  0.002259  0.078911
# DangerouslyWindy       0.000000  0.080882
# Drizzle                0.001371  0.073126
# DrizzleandBreezy       0.000000  0.094650
# Dry                    0.001467  0.087307
# DryandMostlyCloudy     0.000000  0.090909

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 8))
sns.heatmap(weather_counts_by_type_normalize, cmap='viridis')
plt.title('Pokemon type encounter by weather')
plt.xlabel('Type')
plt.ylabel('Weather')
plt.show()

# %% [markdown]
# เมื่อนำมา plot เป็น heatmap พบว่าสภาพอากาศไม่ได้ต่อการเจอโปเกม่อนในแต่ละธาตุที่ปรากฏมากนัก เนื่องด้วยจะเจอ Normal เป็นส่วนใหญ่อยู่แล้ว  แต่ว่าถ้าหากเทียบกับในธาตุด้วยกันเองจะเห็นว่าในบางสภาพอากาศ บางธาตุจะมีโอกาสเกิดมากกว่าปกติ

# %% [markdown]
# ใน Windy and Partly Cloudy จะมีโอกาสเจอโปเกม่อนนอกจากธาตุ Normal ได้ค่อนข้างสูง เนื่องด้วยเจอธาตุ Water กับ Bug ได้มาก ที่น่าแปลกใจคือไม่พบ Flying เลย

# %% [markdown]
# Humid and Partly Cloudy จะเจอธาตุน้ำได้เยอะเช่นกัน ธาตุ Normal จะน้อยลง แต่ว่าก็จะเจอธาตุ Bug ค่อนข้างน้อย

# %% [markdown]
# ธาตุสายฟ้าปกติไม่ค่อยได้พบเห็นมาก แต่ว่าโอกาสพบเจอจะเพิ่มขึ้นมานิดหนึ่งในสภาพอากาศที่มีคำว่า "Breezy" อยู่

# %% [markdown]
# ใน Heavy Rain ธาตุ Ground และ Rock จะมีโอกาสได้เจอมากสุดเมื่อเทียบกับสภาพอากาศอื่น ทั้งสองธาตุเกี่ยวกับผืบดินเช่นกัน

# %% [markdown]
# (ทิ้งไอเดีย) ลองตัดธาตุ Common แล้วคำนวณธาตุแปลกๆดูมั้ย เผื่อเจออะไรน่าสนใจ เช่น ตัด Normal Flying Poison Bug ไรงี้

# %% [markdown]
# ## Pokemon type by time of the day

# %% [markdown]
# ต้องการทราบความสัมพันธ์ของช่วงเวลาของวันว่ามีผลต่อการปรากฏตัวของโปเกมอนในแต่ล่ะธาตุหรือไม่

# %% [markdown]
# เนื่องจากข้อมูลมีระยะห่างมากเกินไปจึงทำการ normalize โดยหารด้วยผลรวมของทั้งแถวเช่นกัน

# %%
TimeOfDay_counts_by_type_1 = pokemon_df.pivot_table(index='appearedTimeOfDay', columns='Type 1', aggfunc='size', fill_value=0)
TimeOfDay_counts_by_type_2 = pokemon_df.pivot_table(index='appearedTimeOfDay', columns='Type 2', aggfunc='size', fill_value=0)

TimeOfDay_counts_by_type_combine = TimeOfDay_counts_by_type_1.add(TimeOfDay_counts_by_type_2, fill_value=0)

TimeOfDay_counts_by_type_normalize = TimeOfDay_counts_by_type_combine.div(TimeOfDay_counts_by_type_combine.sum(axis=1), axis=0)
TimeOfDay_counts_by_type_combine.head()
# Out:
#                        Bug  Dragon  Electric  Fairy  Fighting    Fire  \
# appearedTimeOfDay
# afternoon           9011.0   104.0     541.0    885       272   431.0
# evening             8387.0   127.0     470.0    667       276   531.0
# morning            11767.0   122.0     538.0   1142       504   810.0
# night              28463.0   311.0    1353.0   2423      1630  2825.0
#
#                     Flying   Ghost  Grass  Ground  Ice   Normal  Poison  \
# appearedTimeOfDay
# afternoon          13072.0   482.0   2487     644  170  19532.0   11866
# evening            11478.0   383.0   2330     836  133  18114.0   10573
# morning            16737.0   568.0   3642    1404  176  24899.0   15445
# night              39795.0  1143.0  10147    5013  353  63278.0   37568
#
#                    Psychic  Rock  Steel  Water
# appearedTimeOfDay
# afternoon             3074   422  216.0   6480
# evening               2715   499  199.0   5956
# morning               3653   794  234.0   8180
# night                 7711  2918  481.0  17786

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(TimeOfDay_counts_by_type_normalize, cmap='viridis')
plt.title('Pokemon type encounter by Times of the day')
plt.xlabel('Type')
plt.ylabel('Time of the Day')
plt.show()

# %% [markdown]
# เมื่อนำมา plot เป็น heatmap พบว่าช่วงเวลาของวันไม่ได้มีผลต่อธาตุของโปเกม่อนที่ปรากฏขนาดนั้น

# %% [markdown]
# ## Gym and Pokestop distance by pokemon encounter

# %% [markdown]
# ต้องการทราบความสัมพันธ์ของระยะห่างระหว่างโปเกมอนที่พบกับ Pokestop หรือ Pokemon gym ว่ามีผลต่อความถี่การปรากฏตัวของโปเกมอนหรือไม่

# %%
import matplotlib.pyplot as plt

# Assuming your DataFrame is named 'pokemon_df'

# Create a box plot of the 'pokestopDistanceKm' column
plt.figure(figsize=(8, 6))
plt.boxplot(pokemon_df['pokestopDistanceKm'])
plt.title('Box Plot of Pokestop Distance')
plt.ylabel('Distance (km)')
plt.show()

# %% [markdown]
# จากการนำข้อมูลไปแสดงเป็น box plot พบว่ามี outlier อยู่มากจึงทำการเลือกข้อมูลเพียงส่วนที่อยู่ใน Q1-Q3

# %%
import pandas as pd

# Assuming your DataFrame is named 'pokemon_df'

# Calculate the first quartile (Q1) and third quartile (Q3)
Q1 = pokemon_df['pokestopDistanceKm'].quantile(0.25)
Q3 = pokemon_df['pokestopDistanceKm'].quantile(0.75)

# Calculate the interquartile range (IQR)
IQR = Q3 - Q1

# Calculate the lower and upper bounds of the box
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Filter the data to include only values within the box
filtered_data = pokemon_df[(pokemon_df['pokestopDistanceKm'] >= lower_bound) & (pokemon_df['pokestopDistanceKm'] <= upper_bound)]

# Now 'filtered_data' contains only the rows with 'pokestopDistanceKm' values within the box

# %% [markdown]
# ทำการแบ่งค่าออกเป็นช่วงๆทั้งหมด 10 ช่วง

# %%
import pandas as pd

# Assuming your DataFrame is named 'filtered_data'

# Determine the minimum and maximum values of the 'pokestopDistanceKm' column
min_value = filtered_data['pokestopDistanceKm'].min()
max_value = filtered_data['pokestopDistanceKm'].max()

# Specify the number of intervals (bins) you want
num_intervals = 10  # Adjust this value as needed

# Calculate the interval width
interval_width = (max_value - min_value) / num_intervals

# Create the intervals
bins = [min_value + i * interval_width for i in range(num_intervals)]
bins.append(max_value)  # Append the maximum value to include all data

# Use pd.cut() to bin the values into intervals
interval_labels = [f"{round(bins[i], 2)}-{round(bins[i+1], 2)}" for i in range(len(bins) - 1)]
filtered_data['pokestopDistanceKm_interval'] = pd.cut(filtered_data['pokestopDistanceKm'], bins=bins, labels=interval_labels)

# Count the occurrences of each interval using pd.value_counts()
interval_counts = filtered_data['pokestopDistanceKm_interval'].value_counts().sort_index()

# Create a DataFrame from the interval counts
pokestop_interval_counts_df = pd.DataFrame({'Interval': interval_counts.index, 'Count': interval_counts.values})

# Print the resulting table
print(pokestop_interval_counts_df)
# Out:
#     Interval  Count
# 0   0.0-0.08  86756
# 1  0.08-0.16  66010
# 2  0.16-0.25  35710
# 3  0.25-0.33  24627
# 4  0.33-0.41  16947
# 5  0.41-0.49  12941
# 6  0.49-0.57   9875
# 7  0.57-0.65   6603
# 8  0.65-0.74   4373
# 9  0.74-0.82   3468
# <ipython-input-122-f4ff716f43e1>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['pokestopDistanceKm_interval'] = pd.cut(filtered_data['pokestopDistanceKm'], bins=bins, labels=interval_labels)

# %%
import matplotlib.pyplot as plt

# Plot the histogram
plt.figure(figsize=(10, 6))
plt.bar(pokestop_interval_counts_df['Interval'], pokestop_interval_counts_df['Count'], color='skyblue')
plt.xlabel('Distance Interval (Km)')
plt.ylabel('Number of encounter')
plt.title('Histogram of Pokestop Distance Intervals')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()

# %% [markdown]
# จากการนำข้อมูลที่ได้มาทำเป็นกราฟพบว่า ระยะห่างระหว่างโปเกมอนที่พบกับ Pokestop ว่ามีผลต่อความถี่การปรากฏตัวของโปเกมอน

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))
plt.boxplot(pokemon_df['gymDistanceKm'])
plt.title('Box Plot of Gym Distance')
plt.ylabel('Distance (km)')
plt.show()

# %% [markdown]
# จากการนำข้อมูลไปแสดงเป็น box plot พบว่ามี outlier อยู่มากจึงทำการเลือกข้อมูลเพียงส่วนที่อยู่ใน Q1-Q3 และ ทำการแบ่งค่าออกเป็นช่วงๆทั้งหมด 10 ช่วง เช่นกัน

# %%
Q1 = pokemon_df['gymDistanceKm'].quantile(0.25)
Q3 = pokemon_df['gymDistanceKm'].quantile(0.75)

IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

filtered_data = pokemon_df[(pokemon_df['gymDistanceKm'] >= lower_bound) & (pokemon_df['gymDistanceKm'] <= upper_bound)]


min_value = filtered_data['gymDistanceKm'].min()
max_value = filtered_data['gymDistanceKm'].max()

num_intervals = 10

interval_width = (max_value - min_value) / num_intervals

bins = [min_value + i * interval_width for i in range(num_intervals)]
bins.append(max_value)

interval_labels = [f"{round(bins[i], 2)}-{round(bins[i+1], 2)}" for i in range(len(bins) - 1)]
filtered_data['gymDistanceKm_interval'] = pd.cut(filtered_data['gymDistanceKm'], bins=bins, labels=interval_labels)

interval_counts = filtered_data['gymDistanceKm_interval'].value_counts().sort_index()

gym_interval_counts_df = pd.DataFrame({'Interval': interval_counts.index, 'Count': interval_counts.values})

print(gym_interval_counts_df)
# Out:
#     Interval  Count
# 0   0.0-0.13  46850
# 1  0.13-0.26  68638
# 2   0.26-0.4  55537
# 3   0.4-0.53  35218
# 4  0.53-0.66  17986
# 5  0.66-0.79  10938
# 6  0.79-0.92   8458
# 7  0.92-1.05   6928
# 8  1.05-1.18   3818
# 9  1.18-1.32   2660
# <ipython-input-125-3bd73f1ca04b>:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['gymDistanceKm_interval'] = pd.cut(filtered_data['gymDistanceKm'], bins=bins, labels=interval_labels)

# %%
import matplotlib.pyplot as plt


plt.figure(figsize=(10, 6))
plt.bar(gym_interval_counts_df['Interval'], gym_interval_counts_df['Count'], color='skyblue')
plt.xlabel('Distance Interval (Km)')
plt.ylabel('Number of encounter')
plt.title('Histogram of Gym Distance Intervals')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# จากการนำข้อมูลที่ได้มาทำเป็นกราฟพบว่า ระยะห่างระหว่างโปเกมอนที่พบกับ Pokemon gym ว่ามีผลต่อความถี่การปรากฏตัวของโปเกมอน

# %%
pokemon_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 295982 entries, 0 to 296020
# Data columns (total 22 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   pokemonId           295982 non-null  int64
#  1   latitude            295982 non-null  float64
#  2   longitude           295982 non-null  float64
#  3   appearedLocalTime   295982 non-null  datetime64[ns]
#  4   appearedTimeOfDay   295982 non-null  object
#  5   terrainType         295982 non-null  object
#  6   closeToWater        295982 non-null  bool
#  7   city                295982 non-null  object
#  8   continent           295982 non-null  object
#  9   weather             295982 non-null  object
#  10  temperature         295982 non-null  float64
#  11  windSpeed           295982 non-null  float64
#  12  windBearing         295982 non-null  int64
#  13  pressure            295982 non-null  float64
#  14  weatherIcon         295982 non-null  object
#  15  population_density  295982 non-null  float64
#  16  gymDistanceKm       295982 non-null  float64
#  17  pokestopDistanceKm  295982 non-null  float64
#  18  Name                295982 non-null  object
#  19  Type 1              295982 non-null  object
#  20  Type 2              151194 non-null  object
#  21  rarity              295982 non-null  object
# dtypes: bool(1), datetime64[ns](1), float64(8), int64(2), object(10)
# memory usage: 50.0+ MB

# %% [markdown]
# ## Encounters & Rarity by weather

# %%
unique_weather = pokemon_df['weather'].unique()

print(unique_weather)
# Out:
# ['Foggy' 'Clear' 'PartlyCloudy' 'MostlyCloudy' 'Overcast' 'Rain'
#  'BreezyandOvercast' 'LightRain' 'Drizzle' 'BreezyandPartlyCloudy'
#  'HeavyRain' 'BreezyandMostlyCloudy' 'Breezy' 'Windy' 'WindyandFoggy'
#  'Humid' 'Dry' 'WindyandPartlyCloudy' 'DangerouslyWindy'
#  'DryandMostlyCloudy' 'DryandPartlyCloudy' 'DrizzleandBreezy'
#  'LightRainandBreezy' 'HumidandPartlyCloudy' 'HumidandOvercast'
#  'RainandWindy']

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Group by 'weather' and count the occurrences
weather_counts = pokemon_df.groupby('weather').size().reset_index(name='encounter_count')

# Create a horizontal bar plot
plt.figure(figsize=(10, 6))
bars = plt.barh(weather_counts['weather'], weather_counts['encounter_count'], color='skyblue')

# Add labels and title
plt.ylabel('Weather Type')
plt.xlabel('Number of Pokémon Encounters')
plt.title('Sum of Pokémon Encounters by Weather Type')

# Add data labels to each bar
for bar in bars:
    plt.text(bar.get_width(), bar.get_y() + bar.get_height()/2, f'{bar.get_width():,}', va='center')

plt.tight_layout()  # Adjust layout for better fit

# Display the plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create a pivot table to count occurrences of each combination of 'weather' and 'rarity'
pivot_table = pokemon_df.pivot_table(index='weather', columns='rarity', aggfunc='size', fill_value=0)

# Normalize the data by dividing each cell by the sum of its respective row
pivot_table_normalized = pivot_table.div(pivot_table.sum(axis=0), axis=1)

# Plot heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(pivot_table_normalized, cmap="YlGnBu", annot=True, fmt=".2f", linewidths=.5)
plt.title('Normalized Heatmap of Weather vs Rarity')
plt.xlabel('Rarity')
plt.ylabel('Weather')
plt.show()

# %%
pokemon_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 295982 entries, 0 to 296020
# Data columns (total 22 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   pokemonId           295982 non-null  int64
#  1   latitude            295982 non-null  float64
#  2   longitude           295982 non-null  float64
#  3   appearedLocalTime   295982 non-null  datetime64[ns]
#  4   appearedTimeOfDay   295982 non-null  object
#  5   terrainType         295982 non-null  object
#  6   closeToWater        295982 non-null  bool
#  7   city                295982 non-null  object
#  8   continent           295982 non-null  object
#  9   weather             295982 non-null  object
#  10  temperature         295982 non-null  float64
#  11  windSpeed           295982 non-null  float64
#  12  windBearing         295982 non-null  int64
#  13  pressure            295982 non-null  float64
#  14  weatherIcon         295982 non-null  object
#  15  population_density  295982 non-null  float64
#  16  gymDistanceKm       295982 non-null  float64
#  17  pokestopDistanceKm  295982 non-null  float64
#  18  Name                295982 non-null  object
#  19  Type 1              295982 non-null  object
#  20  Type 2              151194 non-null  object
#  21  rarity              295982 non-null  object
# dtypes: bool(1), datetime64[ns](1), float64(8), int64(2), object(10)
# memory usage: 50.0+ MB

# %% [markdown]
# ## Pokemon Sightings by Terrain and Closeness to water

# %%
pokemon_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 295982 entries, 0 to 296020
# Data columns (total 22 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   pokemonId           295982 non-null  int64
#  1   latitude            295982 non-null  float64
#  2   longitude           295982 non-null  float64
#  3   appearedLocalTime   295982 non-null  datetime64[ns]
#  4   appearedTimeOfDay   295982 non-null  object
#  5   terrainType         295982 non-null  object
#  6   closeToWater        295982 non-null  bool
#  7   city                295982 non-null  object
#  8   continent           295982 non-null  object
#  9   weather             295982 non-null  object
#  10  temperature         295982 non-null  float64
#  11  windSpeed           295982 non-null  float64
#  12  windBearing         295982 non-null  int64
#  13  pressure            295982 non-null  float64
#  14  weatherIcon         295982 non-null  object
#  15  population_density  295982 non-null  float64
#  16  gymDistanceKm       295982 non-null  float64
#  17  pokestopDistanceKm  295982 non-null  float64
#  18  Name                295982 non-null  object
#  19  Type 1              295982 non-null  object
#  20  Type 2              151194 non-null  object
#  21  rarity              295982 non-null  object
# dtypes: bool(1), datetime64[ns](1), float64(8), int64(2), object(10)
# memory usage: 50.0+ MB

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Plot distribution of terrainType with horizontal bars
plt.figure(figsize=(12, 6))
sns.countplot(data=pokemon_df, y='terrainType', order=pokemon_df['terrainType'].value_counts().index)
plt.title('Distribution of Terrain Types')
plt.xlabel('Count')
plt.ylabel('Terrain Type')
plt.show()

# Plot distribution of closeToWater
plt.figure(figsize=(8, 6))
sns.countplot(data=pokemon_df, x='closeToWater')
plt.title('Distribution of Close to Water')
plt.xlabel('Close to Water')
plt.ylabel('Count')
plt.xticks([0, 1], ['False', 'True'])
plt.show()

# Plot relationship between terrainType and closeToWater with horizontal bars
plt.figure(figsize=(12, 6))
sns.countplot(data=pokemon_df, y='terrainType', hue='closeToWater', order=pokemon_df['terrainType'].value_counts().index)
plt.title('Distribution of Terrain Types by Close to Water')
plt.xlabel('Count')
plt.ylabel('Terrain Type')
plt.legend(title='Close to Water', loc='upper right')
plt.show()

# %% [markdown]
# ## Pokemon Sightings by Population Density

# %%
import matplotlib.pyplot as plt
import seaborn as sns

num_bins = 20  # Specify the number of bins
intervals = pd.qcut(pokemon_df['population_density'], q=num_bins, duplicates='drop')

# Step 4: Create bins
pokemon_df['population_density_interval'] = intervals

# Step 5: Analyze and Visualize
plt.figure(figsize=(10, 8))  # Adjust figsize if needed
sns.countplot(y='population_density_interval', data=pokemon_df, palette='viridis')
plt.title('Pokémon Sightings by Population Density Interval')
plt.xlabel('Number of Pokémon Sightings')
plt.ylabel('Population Density Interval')
plt.show()
# Out:
# <ipython-input-134-65d4af14bad4>:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y='population_density_interval', data=pokemon_df, palette='viridis')

# %% [markdown]
# # 3 ) Sampling

# %% [markdown]
# ## Rare-not rare Classification

# %%
rare_counts = pokemon_df['rarity'].value_counts()
print(rare_counts)
# Out:
# rarity
# Common    211618
# Rare       84364
# Name: count, dtype: int64

# %%
pokemon_df['rarity'] = pokemon_df['rarity'].replace({'Uncommon': 'Common',
                                                     'Very Rare': 'Rare',
                                                     'Super Rare': 'Rare'})

# %%
rare_counts = pokemon_df['rarity'].value_counts()
print(rare_counts)
# Out:
# rarity
# Common    211618
# Rare       84364
# Name: count, dtype: int64

# %%
pokemon_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 295982 entries, 0 to 296020
# Data columns (total 24 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   pokemonId                    295982 non-null  int64
#  1   latitude                     295982 non-null  float64
#  2   longitude                    295982 non-null  float64
#  3   appearedLocalTime            295982 non-null  datetime64[ns]
#  4   appearedTimeOfDay            295982 non-null  object
#  5   terrainType                  295982 non-null  object
#  6   closeToWater                 295982 non-null  bool
#  7   city                         295982 non-null  object
#  8   continent                    295982 non-null  object
#  9   weather                      295982 non-null  object
#  10  temperature                  295982 non-null  float64
#  11  windSpeed                    295982 non-null  float64
#  12  windBearing                  295982 non-null  int64
#  13  pressure                     295982 non-null  float64
#  14  weatherIcon                  295982 non-null  object
#  15  population_density           295982 non-null  float64
#  16  gymDistanceKm                295982 non-null  float64
#  17  pokestopDistanceKm           295982 non-null  float64
#  18  Name                         295982 non-null  object
#  19  Type 1                       295982 non-null  object
#  20  Type 2                       151194 non-null  object
#  21  rarity                       295982 non-null  object
#  22  population_density_interval  295982 non-null  category
#  23  is_rare                      295982 non-null  bool
# dtypes: bool(2), category(1), datetime64[ns](1), float64(8), int64(2), object(10)
# memory usage: 58.6+ MB

# %%
pokemon_df['is_rare'] = pokemon_df['rarity'].apply(lambda x: x == 'Rare')

# %%
rare_counts = pokemon_df['is_rare'].value_counts()
print(rare_counts)
# Out:
# is_rare
# False    211618
# True      84364
# Name: count, dtype: int64

# %%
pokemon_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 295982 entries, 0 to 296020
# Data columns (total 24 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   pokemonId                    295982 non-null  int64
#  1   latitude                     295982 non-null  float64
#  2   longitude                    295982 non-null  float64
#  3   appearedLocalTime            295982 non-null  datetime64[ns]
#  4   appearedTimeOfDay            295982 non-null  object
#  5   terrainType                  295982 non-null  object
#  6   closeToWater                 295982 non-null  bool
#  7   city                         295982 non-null  object
#  8   continent                    295982 non-null  object
#  9   weather                      295982 non-null  object
#  10  temperature                  295982 non-null  float64
#  11  windSpeed                    295982 non-null  float64
#  12  windBearing                  295982 non-null  int64
#  13  pressure                     295982 non-null  float64
#  14  weatherIcon                  295982 non-null  object
#  15  population_density           295982 non-null  float64
#  16  gymDistanceKm                295982 non-null  float64
#  17  pokestopDistanceKm           295982 non-null  float64
#  18  Name                         295982 non-null  object
#  19  Type 1                       295982 non-null  object
#  20  Type 2                       151194 non-null  object
#  21  rarity                       295982 non-null  object
#  22  population_density_interval  295982 non-null  category
#  23  is_rare                      295982 non-null  bool
# dtypes: bool(2), category(1), datetime64[ns](1), float64(8), int64(2), object(10)
# memory usage: 58.6+ MB

# %%
selected_columns = [ 'appearedTimeOfDay', 'terrainType', 'closeToWater', 'temperature', 'windSpeed', 'windBearing', 'pressure', 'population_density', 'gymDistanceKm', 'pokestopDistanceKm','is_rare']

pokemon_df_classification = pokemon_df.loc[:, selected_columns]
pokemon_df_classification.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 295982 entries, 0 to 296020
# Data columns (total 11 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   appearedTimeOfDay   295982 non-null  object
#  1   terrainType         295982 non-null  object
#  2   closeToWater        295982 non-null  bool
#  3   temperature         295982 non-null  float64
#  4   windSpeed           295982 non-null  float64
#  5   windBearing         295982 non-null  int64
#  6   pressure            295982 non-null  float64
#  7   population_density  295982 non-null  float64
#  8   gymDistanceKm       295982 non-null  float64
#  9   pokestopDistanceKm  295982 non-null  float64
#  10  is_rare             295982 non-null  bool
# dtypes: bool(2), float64(6), int64(1), object(2)
# memory usage: 31.2+ MB

# %% [markdown]
# ## Sampling For Classification

# %% [markdown]
# Sample Data แบบ Undersampling ตัว Not Rare เพื่อให้ Train แล้วได้ค่า Recall ตัว Rare มากขึ้นกว่าเดิม

# %%
# Filter the rows where is_rare is False
false_rare_rows = pokemon_df_classification[pokemon_df_classification['is_rare'] == False]

# Randomly select 50% of the rows where is_rare is False
rows_to_drop = false_rare_rows.sample(frac=0.70, random_state=1)

# Drop the selected rows from the original DataFrame
pokemon_df_classification = pokemon_df_classification.drop(rows_to_drop.index)

# Reset the index of the resulting DataFrame
pokemon_df_classification = pokemon_df_classification.reset_index(drop=True)

rare_counts = pokemon_df_classification['is_rare'].value_counts()
print(rare_counts)
# Out:
# is_rare
# True     84364
# False    63485
# Name: count, dtype: int64

# %%
pokemon_df_1 = pokemon_df_classification.select_dtypes('object')
pokemon_df_cat = pd.get_dummies(pokemon_df_1, drop_first = True)
pokemon_df_num = pokemon_df_classification.select_dtypes('number')
pokemon_df_prep = pd.concat([pokemon_df_num,pokemon_df_cat,pokemon_df_classification['is_rare']], axis = 1)
pokemon_df_prep.head()
# Out:
#    temperature  windSpeed  windBearing  pressure  population_density  \
# 0         25.5       4.79          269   1018.02           2431.2341
# 1         25.5       4.79          269   1018.02           2431.2341
# 2         15.6       5.84          160   1020.52           4842.1626
# 3         15.6       5.84          160   1020.52           4842.1626
# 4         16.5       6.40          218   1024.45           2102.9775
#
#    gymDistanceKm  pokestopDistanceKm  appearedTimeOfDay_evening  \
# 0       0.049869            0.081776                      False
# 1       0.259156            0.195622                      False
# 2       0.359309            0.109479                      False
# 3       0.210543            0.040364                      False
# 4       0.063400            0.040814                      False
#
#    appearedTimeOfDay_morning  appearedTimeOfDay_night  ...  \
# 0                      False                     True  ...
# 1                      False                     True  ...
# 2                      False                     True  ...
# 3                      False                     True  ...
# 4                      False                     True  ...
#
#    terrainType_Evergreen Needleleaf Forest  terrainType_Grasslands  \
# 0                                    False                   False
# 1                                    False                   False
# 2                                    False                   False
# 3                                    False                   False
# 4                                    False                   False
#
#    terrainType_Mixed Forest  terrainType_Open Shrublands  \
# 0                     False                        False
# 1                     False                        False
# 2                     False                        False
# 3                     False                        False
# 4                     False                        False
#
#    terrainType_Permanent Wetlands  terrainType_Savannas  \
# 0                           False                 False
# 1                           False                 False
# 2                           False                 False
# 3                           False                 False
# 4                           False                 False
#
#    terrainType_Urban and Built-up  terrainType_Water Bodies  \
# 0                           False                     False
# 1                           False                     False
# 2                           False                      True
# 3                           False                      True
# 4                            True                     False
#
#    terrainType_Woody Savannas  is_rare
# 0                       False    False
# 1                       False     True
# 2                       False    False
# 3                       False     True
# 4                       False     True
#
# [5 rows x 24 columns]

# %%
from sklearn.model_selection import train_test_split
pokemon_df_train, pokemon_df_test = train_test_split(pokemon_df_prep, test_size = 0.3)

# %%
pd.crosstab(pokemon_df_train['is_rare'],columns = 'p',normalize = True)
# Out:
# col_0           p
# is_rare
# False    0.428411
# True     0.571589

# %%
pd.crosstab(pokemon_df_test['is_rare'],columns = 'p',normalize = True)
# Out:
# col_0           p
# is_rare
# False    0.431676
# True     0.568324

# %% [markdown]
# ## Sampling for Clustoring

# %% [markdown]
# ต้องการที่จะจำแนก Rare Pokemon ตาม Condition ที่จับได้ ดังนั้นจึงต้องการ Sample แค่ข้อมูล Pokemon แบบ Rare เท่านั้น

# %%
pokemon_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 295982 entries, 0 to 296020
# Data columns (total 24 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   pokemonId                    295982 non-null  int64
#  1   latitude                     295982 non-null  float64
#  2   longitude                    295982 non-null  float64
#  3   appearedLocalTime            295982 non-null  datetime64[ns]
#  4   appearedTimeOfDay            295982 non-null  object
#  5   terrainType                  295982 non-null  object
#  6   closeToWater                 295982 non-null  bool
#  7   city                         295982 non-null  object
#  8   continent                    295982 non-null  object
#  9   weather                      295982 non-null  object
#  10  temperature                  295982 non-null  float64
#  11  windSpeed                    295982 non-null  float64
#  12  windBearing                  295982 non-null  int64
#  13  pressure                     295982 non-null  float64
#  14  weatherIcon                  295982 non-null  object
#  15  population_density           295982 non-null  float64
#  16  gymDistanceKm                295982 non-null  float64
#  17  pokestopDistanceKm           295982 non-null  float64
#  18  Name                         295982 non-null  object
#  19  Type 1                       295982 non-null  object
#  20  Type 2                       151194 non-null  object
#  21  rarity                       295982 non-null  object
#  22  population_density_interval  295982 non-null  category
#  23  is_rare                      295982 non-null  bool
# dtypes: bool(2), category(1), datetime64[ns](1), float64(8), int64(2), object(10)
# memory usage: 58.6+ MB

# %%
rare_pokemon_df = pokemon_df[pokemon_df['is_rare'] == True]
rare_counts = rare_pokemon_df['is_rare'].value_counts()
print(rare_counts)
# Out:
# is_rare
# True    84364
# Name: count, dtype: int64

# %%
selected_columns = ['latitude','longitude', 'temperature', 'windSpeed', 'windBearing', 'pressure', 'population_density', 'gymDistanceKm', 'pokestopDistanceKm']

pokemon_df_selected= rare_pokemon_df.loc[:, selected_columns]
pokemon_df_selected.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 84364 entries, 1 to 296020
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   latitude            84364 non-null  float64
#  1   longitude           84364 non-null  float64
#  2   temperature         84364 non-null  float64
#  3   windSpeed           84364 non-null  float64
#  4   windBearing         84364 non-null  int64
#  5   pressure            84364 non-null  float64
#  6   population_density  84364 non-null  float64
#  7   gymDistanceKm       84364 non-null  float64
#  8   pokestopDistanceKm  84364 non-null  float64
# dtypes: float64(8), int64(1)
# memory usage: 6.4 MB

# %% [markdown]
# # 4 ) Classification

# %% [markdown]
# ## Classification

# %%
#pip install scikit-learn

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
tree = DecisionTreeClassifier(min_samples_leaf=10, max_depth=8)
tree.fit(pokemon_df_train.drop(columns='is_rare'),
         pokemon_df_train['is_rare'])
# Out:
# DecisionTreeClassifier(max_depth=8, min_samples_leaf=10)

# %%
#pip install pydotplus

# %%
#pip install graphviz

# %%
from six import StringIO
from IPython.display import Image
from sklearn.tree import export_graphviz
import pydotplus
dot_data = StringIO()
export_graphviz(tree, out_file=dot_data,
                filled=True, rounded=True,
                special_characters=False,
                rotate=True,
                feature_names=pokemon_df_train.columns[:-1])
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
graph.write_png('tree.png')
Image(graph.create_png())

# %% [markdown]
# ## Variable importance

# %%
pd.DataFrame(dict(Feature=pokemon_df_train.columns[:-1],
                  Value=tree.feature_importances_))\
  .sort_values(by='Value', ascending=False)
# Out:
#                                             Feature     Value
# 4                                population_density  0.470823
# 6                                pokestopDistanceKm  0.105784
# 17                      terrainType_Open Shrublands  0.085333
# 0                                       temperature  0.067272
# 3                                          pressure  0.051767
# 5                                     gymDistanceKm  0.044297
# 21                         terrainType_Water Bodies  0.044114
# 1                                         windSpeed  0.035371
# 2                                       windBearing  0.029319
# 15                           terrainType_Grasslands  0.020329
# 20                   terrainType_Urban and Built-up  0.015923
# 16                         terrainType_Mixed Forest  0.013275
# 11                            terrainType_Croplands  0.010645
# 9                           appearedTimeOfDay_night  0.003185
# 22                       terrainType_Woody Savannas  0.001384
# 8                         appearedTimeOfDay_morning  0.001180
# 13           terrainType_Evergreen Broadleaf Forest  0.000000
# 14          terrainType_Evergreen Needleleaf Forest  0.000000
# 12           terrainType_Deciduous Broadleaf Forest  0.000000
# 10  terrainType_Cropland/Natural Vegetation Mosaics  0.000000
# 18                   terrainType_Permanent Wetlands  0.000000
# 19                             terrainType_Savannas  0.000000
# 7                         appearedTimeOfDay_evening  0.000000

# %% [markdown]
# ## Prediction

# %%
tree.predict(pokemon_df_test.drop(columns='is_rare'))
# Out:
# array([ True,  True,  True, ...,  True,  True, False])

# %%
tree.predict_proba(pokemon_df_test.drop(columns='is_rare'))
# Out:
# array([[0.40115047, 0.59884953],
#        [0.34677783, 0.65322217],
#        [0.3800905 , 0.6199095 ],
#        ...,
#        [0.34677783, 0.65322217],
#        [0.19463087, 0.80536913],
#        [0.50505051, 0.49494949]])

# %% [markdown]
# ## Classification report

# %%
from sklearn.metrics import classification_report

# %%
res = tree.predict(pokemon_df_test.drop(columns='is_rare'))
print(classification_report(y_true=pokemon_df_test['is_rare'].values, y_pred=res))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.56      0.40      0.47     19147
#         True       0.63      0.77      0.69     25208
#
#     accuracy                           0.61     44355
#    macro avg       0.59      0.58      0.58     44355
# weighted avg       0.60      0.61      0.59     44355

# %%
pd.crosstab(pokemon_df['is_rare'], columns='p', normalize=True)
# Out:
# col_0           p
# is_rare
# False    0.714969
# True     0.285031

# %%
pokemon_df_test.shape
# Out:
# (44355, 24)

# %%
pd.crosstab(index=res,columns=pokemon_df_test['is_rare'])
# Out:
# is_rare  False  True
# row_0
# False     7596   5890
# True     11551  19318

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

# %%
lda = LinearDiscriminantAnalysis()
lda.fit(pokemon_df_train.drop(columns='is_rare'), pokemon_df_train['is_rare'])
# Out:
# LinearDiscriminantAnalysis()

# %%
pd.DataFrame(dict(Feature = pokemon_df_train.columns[:-1],
                  Coefficient = lda.coef_[0]))
# Out:
#                                             Feature  Coefficient
# 0                                       temperature    -0.006867
# 1                                         windSpeed     0.004650
# 2                                       windBearing    -0.000107
# 3                                          pressure    -0.012430
# 4                                population_density     0.000052
# 5                                     gymDistanceKm    -0.000627
# 6                                pokestopDistanceKm     0.000615
# 7                         appearedTimeOfDay_evening     0.002129
# 8                         appearedTimeOfDay_morning    -0.016671
# 9                           appearedTimeOfDay_night    -0.017715
# 10  terrainType_Cropland/Natural Vegetation Mosaics    -0.520689
# 11                            terrainType_Croplands    -0.518055
# 12           terrainType_Deciduous Broadleaf Forest    -0.331290
# 13           terrainType_Evergreen Broadleaf Forest    -0.201102
# 14          terrainType_Evergreen Needleleaf Forest    -0.250054
# 15                           terrainType_Grasslands    -0.318595
# 16                         terrainType_Mixed Forest    -0.527091
# 17                      terrainType_Open Shrublands     0.311294
# 18                   terrainType_Permanent Wetlands    -1.316517
# 19                             terrainType_Savannas    -0.329466
# 20                   terrainType_Urban and Built-up    -0.127732
# 21                         terrainType_Water Bodies     0.422831
# 22                       terrainType_Woody Savannas    -0.306894

# %%
lda.predict_proba(pokemon_df_test.drop(columns='is_rare'))
# Out:
# array([[0.43127724, 0.56872276],
#        [0.46640571, 0.53359429],
#        [0.31334627, 0.68665373],
#        ...,
#        [0.29105639, 0.70894361],
#        [0.40523981, 0.59476019],
#        [0.44733694, 0.55266306]])

# %%
res_lda = lda.predict(pokemon_df_test.drop(columns='is_rare'))
print(classification_report(y_true=pokemon_df_test['is_rare'].values, y_pred=res_lda))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.53      0.31      0.39     19147
#         True       0.60      0.79      0.68     25208
#
#     accuracy                           0.58     44355
#    macro avg       0.56      0.55      0.54     44355
# weighted avg       0.57      0.58      0.56     44355

# %%
res_lda_p = lda.predict_proba(pokemon_df_test.drop(columns='is_rare'))[:,1] #

# %%
import numpy as np
res_lda_new_class = np.where(res_lda_p > 0.25, 1, 0)

# %%
print(classification_report(y_true=pokemon_df_test['is_rare'].values, y_pred=res_lda_new_class))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.00      0.00      0.00     19147
#         True       0.57      1.00      0.72     25208
#
#     accuracy                           0.57     44355
#    macro avg       0.28      0.50      0.36     44355
# weighted avg       0.32      0.57      0.41     44355
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# # 5 ) Clustering

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
df_prep = pd.DataFrame(scaler.fit_transform(pokemon_df_selected),index=pokemon_df_selected.index)

# %%
df_prep.hist()
# Out:
# array([[<Axes: title={'center': '0'}>, <Axes: title={'center': '1'}>,
#         <Axes: title={'center': '2'}>],
#        [<Axes: title={'center': '3'}>, <Axes: title={'center': '4'}>,
#         <Axes: title={'center': '5'}>],
#        [<Axes: title={'center': '6'}>, <Axes: title={'center': '7'}>,
#         <Axes: title={'center': '8'}>]], dtype=object)

# %%
from sklearn.cluster import KMeans

cls = KMeans(n_clusters=9)
cls.fit(df_prep)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=9)

# %%
cls.labels_
# Out:
# array([2, 1, 7, ..., 6, 4, 5], dtype=int32)

# %%
cls.cluster_centers_
# Out:
# array([[-4.01568804e-01,  1.10395032e+00,  5.98518160e-01,
#          1.22087893e-01,  1.31835691e-01, -3.97287934e-01,
#          2.94284926e+00, -8.00830114e-02, -7.04456969e-02],
#        [ 1.38774666e-01, -1.02768524e+00, -9.89363463e-01,
#         -5.67187088e-01,  4.83145702e-01, -3.48929454e-01,
#         -1.13857429e-01, -5.94215976e-02, -4.05205025e-02],
#        [-2.72439182e-01, -8.66135530e-01,  1.01208014e+00,
#          4.50515666e-01,  5.78869003e-01, -8.01681626e-01,
#         -1.67659756e-01, -2.34758859e-02,  5.23567941e-02],
#        [-1.64699687e+00,  1.53516253e+00,  7.23462893e-01,
#          1.53969845e-01,  2.98807986e-01,  4.31511785e-02,
#         -6.92386399e-01,  2.00095460e+01,  5.96900351e+01],
#        [ 7.69581331e-01,  6.97926178e-01, -5.34596214e-01,
#          8.73431153e-01,  7.26305321e-01, -3.02028953e-01,
#         -2.36967993e-01, -5.14342097e-02, -2.28713547e-02],
#        [ 5.90549473e-01,  7.04691086e-01, -3.82920703e-01,
#         -5.88359252e-01, -3.18887983e-01,  5.46959918e-01,
#         -3.07106500e-01, -5.93688207e-02, -3.31033663e-02],
#        [-1.71876381e-01, -5.67751304e-01,  4.85363595e-01,
#         -1.03766129e-01, -9.38902638e-01,  5.37339770e-01,
#         -1.77540860e-01, -3.21841319e-02, -4.64688687e-03],
#        [-3.47494882e+00,  1.75033054e+00, -3.33092867e-01,
#          1.62848752e-01,  1.32777011e-01,  1.81623885e-01,
#          6.21703409e-02, -3.77747965e-02, -3.58389544e-02],
#        [-1.86638495e+00,  1.88163394e+00,  1.00651245e+00,
#         -2.82524178e-01,  3.79196837e-01, -6.58508277e-01,
#         -7.02311036e-01,  1.36974398e+01,  6.82836110e-01]])

# %%
import seaborn as sns

sns.clustermap(pd.DataFrame(cls.cluster_centers_,columns=['latitude','longitude', 'temperature', 'windSpeed', 'windBearing', 'pressure', 'population_density', 'gymDistanceKm', 'pokestopDistanceKm']), cmap='RdYlBu',
               vmin=-1, vmax=1)

# %%
pokemon_df_selected['cluster'] = cls.labels_
pokemon_df_selected.head(10)
# Out:
#      latitude   longitude  temperature  windSpeed  windBearing  pressure  \
# 1   20.523695  -97.461167         25.5       4.79          269   1018.02
# 4   47.666454 -122.311628         15.6       5.84          160   1020.52
# 6  -31.954245  115.852038         16.5       6.40          218   1024.45
# 7   26.235257  -98.197591         28.0      11.26          142   1016.69
# 8   20.525554  -97.458800         25.5       4.79          269   1018.02
# 10  32.930646  -84.339867         23.7       3.94          253   1020.12
# 11  32.943651  -84.334443         23.7       3.94          253   1020.12
# 19 -31.954346  115.851576         16.5       6.40          218   1024.45
# 21  26.235527  -98.197677         28.0      11.26          142   1016.69
# 22  20.524085  -97.458547         25.5       4.79          269   1018.02
#
#     population_density  gymDistanceKm  pokestopDistanceKm  cluster
# 1           2431.23410       0.259156            0.195622        2
# 4           4842.16260       0.210543            0.040364        1
# 6           2102.97750       0.063400            0.040814        7
# 7            849.44226       0.818592            0.958176        6
# 8           2431.23410       0.109303            0.116773        2
# 10            86.49836       1.751675            1.089211        6
# 11            86.49836       0.321950            0.511109        6
# 19          2102.97750       0.062261            0.045231        7
# 21           849.44226       0.789831            0.929790        6
# 22          2431.23410       0.173178            0.124377        2

# %% [markdown]
# # Unused

# %%
import numpy as np

def sample_pokemon_ids(pokemon_ids, num_samples):
    pokemon_ids_sorted = np.sort(pokemon_ids)
    random_numbers = np.random.rand(num_samples)
    sampled_pokemon_ids = np.interp(random_numbers, np.linspace(0, 1, len(pokemon_ids_sorted)), pokemon_ids_sorted)
    return sampled_pokemon_ids.astype(int)

# %%
sampled_ids = sample_pokemon_ids(pokemon_df['pokemonId'], num_samples=20)
print(sampled_ids)
# Out:
# [ 52  16  61  79  69  16  46  19  74 116  19   7  16 133  92  16  29  32
#   52  69]

# %%
import numpy as np
import pandas as pd

def sample_appeared_local_time(existing_timestamps, num_samples):
    min_timestamp = existing_timestamps.min()
    max_timestamp = existing_timestamps.max()
    random_timestamps = pd.to_datetime(np.random.randint(min_timestamp.value, max_timestamp.value, num_samples))
    return random_timestamps

# %%
sampled_times = sample_appeared_local_time(pokemon_df['appearedLocalTime'], num_samples=20)
print(sampled_times)
# Out:
# DatetimeIndex(['2016-09-07 11:22:08.058081235',
#                '2016-09-03 11:26:24.571951226',
#                '2016-09-05 08:21:39.082377409',
#                '2016-09-05 08:22:44.624601650',
#                '2016-09-07 23:16:21.809870061',
#                '2016-09-03 15:13:25.727184945',
#                '2016-09-03 22:03:55.377124573',
#                '2016-09-06 12:57:14.202226976',
#                '2016-09-05 03:29:02.399586179',
#                '2016-09-05 08:05:40.378008463',
#                '2016-09-03 19:15:59.912475422',
#                '2016-09-04 20:21:11.125120196',
#                '2016-09-03 18:42:27.328293648',
#                '2016-09-06 07:31:59.863518651',
#                '2016-09-08 00:39:49.977801005',
#                '2016-09-07 01:31:36.634590842',
#                '2016-09-08 03:36:32.358429248',
#                '2016-09-05 00:51:24.139286979',
#                '2016-09-06 15:24:22.701369864',
#                '2016-09-04 14:49:56.790866538'],
#               dtype='datetime64[ns]', freq=None)

# %%
def sample_latitude_longitude(latitudes, longitudes, num_samples):
    # Randomly select indices to sample
    indices = np.random.choice(len(latitudes), size=num_samples, replace=True)

    # Retrieve latitude and longitude values at the selected indices
    sampled_latitudes = latitudes.iloc[indices]
    sampled_longitudes = longitudes.iloc[indices]

    return sampled_latitudes, sampled_longitudes

# %%
sampled_latitudes, sampled_longitudes = sample_latitude_longitude(pokemon_df['latitude'], pokemon_df['longitude'], num_samples=20)
for lat, lon in zip(sampled_latitudes, sampled_longitudes):
    print(lat, lon)
# Out:
# 34.141963 -119.187622
# 44.869032 -0.703739
# 33.765819 -84.389644
# 44.421623 11.911274
# 41.851002 -88.30582
# 44.429839 26.099955
# 38.48176 -90.389588
# 48.865653 2.296113
# 50.329302 13.547565
# 22.46833 114.003874
# 44.335334 -72.756113
# 45.380598 -122.760619
# 59.215221 9.606202
# 29.969748 -90.061503
# 52.997818 6.556937
# 50.053978 14.540046
# 49.833695 18.181438
# 34.009682 -118.497208
# 40.104786 -85.651957
# 30.421615 -91.049898
